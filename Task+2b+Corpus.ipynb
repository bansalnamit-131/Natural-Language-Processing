# %%
from nltk.corpus import stopwords
stopwords.words("arabic")
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
import nltk
entries=nltk.corpus.cmudict.entries()
len(entries)
for entry in entries[1000:1005]:
    print(entry)
# Out:
# ("addidas's", ['AH0', 'D', 'IY1', 'D', 'AH0', 'S', 'IH0', 'Z'])
# ('addie', ['AE1', 'D', 'IY0'])
# ('adding', ['AE1', 'D', 'IH0', 'NG'])
# ('addington', ['AE1', 'D', 'IH0', 'NG', 'T', 'AH0', 'N'])
# ('addis', ['AA1', 'D', 'IH0', 'S'])

# %%
from nltk.corpus import wordnet as wn
word=input('Enter the word to search : ')
a=wn.synsets(word)
for i in a:
    print(i.lemma_names()[0],':',i.definition())
    print('Synonyms :',i.lemma_names())
# Out:
# Enter the word to search : home
# home : where you live at a particular time
# Synonyms : ['home', 'place']
# dwelling : housing that someone is living in
# Synonyms : ['dwelling', 'home', 'domicile', 'abode', 'habitation', 'dwelling_house']
# home : the country or state or city where you live
# Synonyms : ['home']
# home_plate : (baseball) base consisting of a rubber slab where the batter stands; it must be touched by a base runner in order to score
# Synonyms : ['home_plate', 'home_base', 'home', 'plate']
# base : the place where you are stationed and from which missions start and end
# Synonyms : ['base', 'home']
# home : place where something began and flourished
# Synonyms : ['home']
# home : an environment offering affection and security
# Synonyms : ['home']
# family : a social unit living together
# Synonyms : ['family', 'household', 'house', 'home', 'menage']
# home : an institution where people are cared for
# Synonyms : ['home', 'nursing_home', 'rest_home']
# ...

# %%
texts=["""Hello my name is Namit Bansal,I am studying in 3rd year B.tech Computer Scince Engineering in VIT vellore.I am from Shamli which is in Uttar Pradesh."""] #between 3 quotes

for text in texts:
    sentences=nltk.sent_tokenize(text)
    for sentence in sentences:
        word=nltk.word_tokenize(sentence)
        tagged_words= nltk.pos_tag(word)
        print(tagged_words)
# Out:
# [('Hello', 'NNP'), ('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Namit', 'NNP'), ('Bansal', 'NNP'), (',', ','), ('I', 'PRP'), ('am', 'VBP'), ('studying', 'VBG'), ('in', 'IN'), ('3rd', 'CD'), ('year', 'NN'), ('B.tech', 'NNP'), ('Computer', 'NNP'), ('Scince', 'NNP'), ('Engineering', 'NNP'), ('in', 'IN'), ('VIT', 'NNP'), ('vellore.I', 'FW'), ('am', 'VBP'), ('from', 'IN'), ('Shamli', 'NNP'), ('which', 'WDT'), ('is', 'VBZ'), ('in', 'IN'), ('Uttar', 'NNP'), ('Pradesh', 'NNP'), ('.', '.')]

# %%
from nltk.tokenize import TweetTokenizer
text="It was so lit #daytoremember :D"
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['It', 'was', 'so', 'lit', '#daytoremember', ':D']
